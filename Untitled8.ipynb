# %% [markdown]
# <a href="https://colab.research.google.com/github/sreelakshmi5013/phyton/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
In [ ]:
# Python program to find area of circle and perimeter of a circle using math function.

import math
class circle():
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*(self.radius**2)
    def perimeter(self):
        return 2*math.pi*self.radius
 
r=int(input("Enter radius of circle: "))
obj=circle(r)
print("Area of circle:",round(obj.area(),2))
print("Perimeter of circle:",round(obj.perimeter(),2))
Enter radius of circle: 4
Area of circle: 50.27
Perimeter of circle: 25.13

In [ ]:
# Python program to find the area of a regular polygon using math funtion.

from math import tan 
  
def polyarea(n, a): 
      
    if (a < 0 and n < 0): 
        return -1
  
    A = (a * a * n) / (4 * tan((180 / n) *3.14159 / 180)) 
                      
  
    return A 
  
if __name__ == '__main__': 
 a=int(input("Enter the value of a: "))
 n=int(input("Enter the value of n: "))
  
print('{0:.6}'.format(polyarea(n, a)))
Enter the value of a: 9
Enter the value of n: 6
210.444

In [20]:
# Python program to find area of segment of circle formula using math funtion.

def sectorarea():
    pi=22/7
    radius = float(input('Radius of Circle: '))
    angle = float(input('angle measure: '))
    if angle >= 360:
        print("Angle is not possible")
        return
    sur_area = (pi*radius**2) * (angle/360)
    print("Sector Area: ", sur_area)
sectorarea()
Radius of Circle: 4
angle measure: 45
Sector Area:  6.285714285714286

In [21]:
# Python program to shuffle the list.

from random import shuffle
l1=[100,1,2,3,30,40,"hai","hello"]
shuffle(l1)
print(l1)
[100, 40, 2, 'hai', 'hello', 3, 30, 1]

In [29]:
# Python program generate random numbers between 1,10000 and difference between each random number is 50.

import random

print("Random integer from 0 to 10000")
num1 = random.randrange(0,10000,50)
print("Random integer: ", num1)
Random integer from 0 to 10000
Random integer:  6650

In [ ]:

Python programs by using math module:
In [38]:
math.sin(60)
Out[38]:
-0.3048106211022167
In [34]:
pi=22/7
math.cos(pi)
Out[34]:
-0.999999200533553
In [35]:
math.tan(90)
Out[35]:
-1.995200412208242
In [36]:
math.degrees()
Out[36]:
49.61960058796128
In [39]:
math.sin(0.8660254037844386)
Out[39]:
0.7617599814162892
In [40]:
math.sqrt(400)
Out[40]:
20.0
In [41]:
math.pow(5,math.e)
Out[41]:
79.43235916621322
In [42]:
math.log(1024,10)
Out[42]:
3.0102999566398116
In [43]:
math.log(1024,2)
Out[43]:
10.0
In [44]:
math.floor(23.56)
Out[44]:
23
In [45]:
math.ceil(23.56)
Out[45]:
24
In [ ]:
